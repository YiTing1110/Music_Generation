# %%
from music21 import *
import warnings
warnings.filterwarnings("ignore")

# %%
# 加載MIDI文件
filepath = "./rock/00-711.mid"
music = converter.parse(filepath)

# %% [markdown]
# * 樂譜（Score）
#     * 部分（Part）
#         * 小節（Measure）
#             * 音符（Note）
#             * 和弦（Chord）
#             * 休止符（Rest）

# %%
music.show("text")
# Out:
# {0.0} <music21.metadata.Metadata object at 0x23b694ab910>
# {0.0} <music21.stream.Part 0x23b694ab970>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.clef.BassClef>
#         {0.0} <music21.tempo.MetronomeMark Quarter=190.0>
#         {0.0} <music21.key.Key of C major>
#         {0.0} <music21.meter.TimeSignature 4/4>
#         {0.0} <music21.note.Rest quarter>
#         {1.0} <music21.instrument.ElectricGuitar 'Lead: Electric Guitar'>
#         {1.0} <music21.note.Rest dotted-half>
#     {4.0} <music21.stream.Measure 2 offset=4.0>
#         {0.0} <music21.note.Rest whole>
#     {8.0} <music21.stream.Measure 3 offset=8.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note E>
#         {3.5} <music21.note.Note A>
#     {12.0} <music21.stream.Measure 4 offset=12.0>
#         {0.0} <music21.note.Note A>
#         {0.5} <music21.note.Note E>
#         {1.0} <music21.note.Note C>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C>
#     {16.0} <music21.stream.Measure 5 offset=16.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note E>
#         {3.5} <music21.note.Note A>
#     {20.0} <music21.stream.Measure 6 offset=20.0>
#         {0.0} <music21.note.Note A>
#         {0.5} <music21.note.Note E>
#         {1.0} <music21.note.Note C>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C>
#     {24.0} <music21.stream.Measure 7 offset=24.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note E>
#         {3.5} <music21.note.Note A>
#     {28.0} <music21.stream.Measure 8 offset=28.0>
#         {0.0} <music21.note.Note A>
#         {0.5} <music21.note.Note E>
#         {1.0} <music21.note.Note C>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C>
#     {32.0} <music21.stream.Measure 9 offset=32.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {36.0} <music21.stream.Measure 10 offset=36.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.chord.Chord E4 C4 A3>
#         {1.5} <music21.chord.Chord E4 C4 A3>
#         {2.0} <music21.chord.Chord A3 C4 E4>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note G>
#         {3.5} <music21.note.Note G#>
#     {40.0} <music21.stream.Measure 11 offset=40.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {44.0} <music21.stream.Measure 12 offset=44.0>
#         {0.0} <music21.note.Note F>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Rest eighth>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note G>
#         {3.5} <music21.note.Note G#>
#     {48.0} <music21.stream.Measure 13 offset=48.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {52.0} <music21.stream.Measure 14 offset=52.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.chord.Chord E4 C4 A3>
#         {1.5} <music21.chord.Chord E4 C4 A3>
#         {2.0} <music21.chord.Chord A3 C4 E4>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note G>
#         {3.5} <music21.note.Note G#>
#     {56.0} <music21.stream.Measure 15 offset=56.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {60.0} <music21.stream.Measure 16 offset=60.0>
#         {0.0} <music21.note.Note F>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Rest eighth>
#         {2.5} <music21.note.Note A>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C#>
#     {64.0} <music21.stream.Measure 17 offset=64.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note F>
#         {3.0} <music21.note.Note E>
#     {68.0} <music21.stream.Measure 18 offset=68.0>
#         {0.0} <music21.note.Note D>
#         {1.0} <music21.chord.Chord A3 F4 D4>
#         {1.5} <music21.chord.Chord A3 F4 D4>
#         {2.0} <music21.chord.Chord D4 F4 A3>
#         {2.5} <music21.note.Note A>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C#>
#     {72.0} <music21.stream.Measure 19 offset=72.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note F>
#         {3.0} <music21.note.Note E>
#     {76.0} <music21.stream.Measure 20 offset=76.0>
#         {0.0} <music21.note.Note B->
#         {1.0} <music21.note.Note A>
#         {2.0} <music21.note.Rest eighth>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note G>
#         {3.5} <music21.note.Note G#>
#     {80.0} <music21.stream.Measure 21 offset=80.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {84.0} <music21.stream.Measure 22 offset=84.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.chord.Chord E4 C4 A3>
#         {1.5} <music21.chord.Chord E4 C4 A3>
#         {2.0} <music21.chord.Chord A3 C4 E4>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note G>
#         {3.5} <music21.note.Note G#>
#     {88.0} <music21.stream.Measure 23 offset=88.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {92.0} <music21.stream.Measure 24 offset=92.0>
#         {0.0} <music21.note.Note F>
#         {1.0} <music21.note.Note E>
#         {3.0} <music21.note.Rest quarter>
#     {96.0} <music21.stream.Measure 25 offset=96.0>
#         {0.0} <music21.note.Note E>
#         {2.0} <music21.note.Note F>
#         {3.0} <music21.note.Note E>
#     {100.0} <music21.stream.Measure 26 offset=100.0>
#         {0.0} <music21.note.Note B>
#     {104.0} <music21.stream.Measure 27 offset=104.0>
#         {0.0} <music21.note.Note A>
#         {2.0} <music21.note.Note B->
#         {3.0} <music21.note.Note A>
#     {108.0} <music21.stream.Measure 28 offset=108.0>
#         {0.0} <music21.note.Note E>
#     {112.0} <music21.stream.Measure 29 offset=112.0>
#         {0.0} <music21.note.Note F>
#         {1.5} <music21.note.Note C>
#         {3.0} <music21.note.Note F>
#     {116.0} <music21.stream.Measure 30 offset=116.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note B>
#         {3.0} <music21.note.Note D>
#     {120.0} <music21.stream.Measure 31 offset=120.0>
#         {0.0} <music21.note.Note E>
#         {1.0} <music21.note.Note E>
#         {1.5} <music21.note.Note B>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Rest eighth>
#         {3.5} <music21.note.Note G>
#     {124.0} <music21.stream.Measure 32 offset=124.0>
#         {0.0} <music21.note.Note E>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Note E>
#         {1.5} <music21.note.Note B>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note B>
#         {3.5} <music21.note.Note A>
#     {128.0} <music21.stream.Measure 33 offset=128.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note E>
#         {3.5} <music21.note.Note A>
#     {132.0} <music21.stream.Measure 34 offset=132.0>
#         {0.0} <music21.note.Note A>
#         {0.5} <music21.note.Note E>
#         {1.0} <music21.note.Note C>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C>
#     {136.0} <music21.stream.Measure 35 offset=136.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note E>
#         {3.5} <music21.note.Note A>
#     {140.0} <music21.stream.Measure 36 offset=140.0>
#         {0.0} <music21.note.Note A>
#         {0.5} <music21.note.Note E>
#         {1.0} <music21.note.Note C>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C>
#     {144.0} <music21.stream.Measure 37 offset=144.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note E>
#         {3.5} <music21.note.Note A>
#     {148.0} <music21.stream.Measure 38 offset=148.0>
#         {0.0} <music21.note.Note A>
#         {0.5} <music21.note.Note E>
#         {1.0} <music21.note.Note C>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C>
#     {152.0} <music21.stream.Measure 39 offset=152.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {156.0} <music21.stream.Measure 40 offset=156.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.chord.Chord E4 C4 A3>
#         {1.5} <music21.chord.Chord E4 C4 A3>
#         {2.0} <music21.chord.Chord A3 C4 E4>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note G>
#         {3.5} <music21.note.Note G#>
#     {160.0} <music21.stream.Measure 41 offset=160.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {164.0} <music21.stream.Measure 42 offset=164.0>
#         {0.0} <music21.note.Note F>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Rest eighth>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note G>
#         {3.5} <music21.note.Note G#>
#     {168.0} <music21.stream.Measure 43 offset=168.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {172.0} <music21.stream.Measure 44 offset=172.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.chord.Chord E4 C4 A3>
#         {1.5} <music21.chord.Chord E4 C4 A3>
#         {2.0} <music21.chord.Chord A3 C4 E4>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note G>
#         {3.5} <music21.note.Note G#>
#     {176.0} <music21.stream.Measure 45 offset=176.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {180.0} <music21.stream.Measure 46 offset=180.0>
#         {0.0} <music21.note.Note F>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Rest eighth>
#         {2.5} <music21.note.Note A>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C#>
#     {184.0} <music21.stream.Measure 47 offset=184.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note F>
#         {3.0} <music21.note.Note E>
#     {188.0} <music21.stream.Measure 48 offset=188.0>
#         {0.0} <music21.note.Note D>
#         {1.0} <music21.chord.Chord A3 F4 D4>
#         {1.5} <music21.chord.Chord A3 F4 D4>
#         {2.0} <music21.chord.Chord D4 F4 A3>
#         {2.5} <music21.note.Note A>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C#>
#     {192.0} <music21.stream.Measure 49 offset=192.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note F>
#         {3.0} <music21.note.Note E>
#     {196.0} <music21.stream.Measure 50 offset=196.0>
#         {0.0} <music21.note.Note B->
#         {1.0} <music21.note.Note A>
#         {2.0} <music21.note.Rest eighth>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note G>
#         {3.5} <music21.note.Note G#>
#     {200.0} <music21.stream.Measure 51 offset=200.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {204.0} <music21.stream.Measure 52 offset=204.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.chord.Chord E4 C4 A3>
#         {1.5} <music21.chord.Chord E4 C4 A3>
#         {2.0} <music21.chord.Chord A3 C4 E4>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note G>
#         {3.5} <music21.note.Note G#>
#     {208.0} <music21.stream.Measure 53 offset=208.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {212.0} <music21.stream.Measure 54 offset=212.0>
#         {0.0} <music21.note.Note F>
#         {1.0} <music21.note.Note E>
#         {3.0} <music21.note.Rest quarter>
#     {216.0} <music21.stream.Measure 55 offset=216.0>
#         {0.0} <music21.note.Note E>
#         {2.0} <music21.note.Note F>
#         {3.0} <music21.note.Note E>
#     {220.0} <music21.stream.Measure 56 offset=220.0>
#         {0.0} <music21.note.Note C>
#         {2.0} <music21.note.Note B>
#     {224.0} <music21.stream.Measure 57 offset=224.0>
#         {0.0} <music21.note.Note A>
#     {228.0} <music21.stream.Measure 58 offset=228.0>
#         {0.0} <music21.chord.Chord E3 A3 C#4 E4>
#     {232.0} <music21.stream.Measure 59 offset=232.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note D>
#         {3.5} <music21.note.Note C>
#     {236.0} <music21.stream.Measure 60 offset=236.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note D>
#         {2.5} <music21.note.Note C>
#         {3.0} <music21.note.Note A>
#     {240.0} <music21.stream.Measure 61 offset=240.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note G>
#         {2.0} <music21.note.Note A>
#         {3.5} <music21.note.Note G>
#     {244.0} <music21.stream.Measure 62 offset=244.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note G>
#         {2.0} <music21.note.Note A>
#         {2.5} <music21.note.Note G>
#         {3.0} <music21.note.Note E>
#         {3.5} <music21.note.Rest eighth>
#     {248.0} <music21.stream.Measure 63 offset=248.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note D>
#         {3.5} <music21.note.Note C>
#     {252.0} <music21.stream.Measure 64 offset=252.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note D>
#         {2.5} <music21.note.Note C>
#         {3.0} <music21.note.Note A>
#     {256.0} <music21.stream.Measure 65 offset=256.0>
#         {0.0} <music21.chord.Chord A2 E3>
#         {2.0} <music21.chord.Chord G2 D3>
#     {260.0} <music21.stream.Measure 66 offset=260.0>
#         {0.0} <music21.chord.Chord F2 C3>
#         {2.0} <music21.chord.Chord E2 B2>
#         {3.0} <music21.note.Rest quarter>
#     {264.0} <music21.stream.Measure 67 offset=264.0>
#         {0.0} <music21.note.Rest whole>
#     {268.0} <music21.stream.Measure 68 offset=268.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note E>
#         {3.5} <music21.note.Note A>
#     {272.0} <music21.stream.Measure 69 offset=272.0>
#         {0.0} <music21.note.Note A>
#         {0.5} <music21.note.Note E>
#         {1.0} <music21.note.Note C>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C>
#     {276.0} <music21.stream.Measure 70 offset=276.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note E>
#         {3.5} <music21.note.Note A>
#     {280.0} <music21.stream.Measure 71 offset=280.0>
#         {0.0} <music21.note.Note A>
#         {0.5} <music21.note.Note E>
#         {1.0} <music21.note.Note C>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C>
#     {284.0} <music21.stream.Measure 72 offset=284.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note E>
#         {3.5} <music21.note.Note A>
#     {288.0} <music21.stream.Measure 73 offset=288.0>
#         {0.0} <music21.note.Note A>
#         {0.5} <music21.note.Note E>
#         {1.0} <music21.note.Note C>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C>
#     {292.0} <music21.stream.Measure 74 offset=292.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {296.0} <music21.stream.Measure 75 offset=296.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.chord.Chord E4 C4 A3>
#         {1.5} <music21.chord.Chord E4 C4 A3>
#         {2.0} <music21.chord.Chord A3 C4 E4>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note G>
#         {3.5} <music21.note.Note G#>
#     {300.0} <music21.stream.Measure 76 offset=300.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {304.0} <music21.stream.Measure 77 offset=304.0>
#         {0.0} <music21.note.Note F>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Rest eighth>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note G>
#         {3.5} <music21.note.Note G#>
#     {308.0} <music21.stream.Measure 78 offset=308.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {312.0} <music21.stream.Measure 79 offset=312.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.chord.Chord E4 C4 A3>
#         {1.5} <music21.chord.Chord E4 C4 A3>
#         {2.0} <music21.chord.Chord A3 C4 E4>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note G>
#         {3.5} <music21.note.Note G#>
#     {316.0} <music21.stream.Measure 80 offset=316.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {320.0} <music21.stream.Measure 81 offset=320.0>
#         {0.0} <music21.note.Note F>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Rest eighth>
#         {2.5} <music21.note.Note A>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C#>
#     {324.0} <music21.stream.Measure 82 offset=324.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note F>
#         {3.0} <music21.note.Note E>
#     {328.0} <music21.stream.Measure 83 offset=328.0>
#         {0.0} <music21.note.Note D>
#         {1.0} <music21.chord.Chord A3 F4 D4>
#         {1.5} <music21.chord.Chord A3 F4 D4>
#         {2.0} <music21.chord.Chord D4 F4 A3>
#         {2.5} <music21.note.Note A>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C#>
#     {332.0} <music21.stream.Measure 84 offset=332.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note F>
#         {3.0} <music21.note.Note E>
#     {336.0} <music21.stream.Measure 85 offset=336.0>
#         {0.0} <music21.note.Note B->
#         {1.0} <music21.note.Note A>
#         {2.0} <music21.note.Rest eighth>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note G>
#         {3.5} <music21.note.Note G#>
#     {340.0} <music21.stream.Measure 86 offset=340.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {344.0} <music21.stream.Measure 87 offset=344.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.chord.Chord E4 C4 A3>
#         {1.5} <music21.chord.Chord E4 C4 A3>
#         {2.0} <music21.chord.Chord A3 C4 E4>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note G>
#         {3.5} <music21.note.Note G#>
#     {348.0} <music21.stream.Measure 88 offset=348.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {352.0} <music21.stream.Measure 89 offset=352.0>
#         {0.0} <music21.note.Note F>
#         {1.0} <music21.note.Note E>
#         {3.0} <music21.note.Rest quarter>
#     {356.0} <music21.stream.Measure 90 offset=356.0>
#         {0.0} <music21.note.Note E>
#         {2.0} <music21.note.Note F>
#         {3.0} <music21.note.Note E>
#     {360.0} <music21.stream.Measure 91 offset=360.0>
#         {0.0} <music21.note.Note B>
#     {364.0} <music21.stream.Measure 92 offset=364.0>
#         {0.0} <music21.note.Note A>
#         {2.0} <music21.note.Note B->
#         {3.0} <music21.note.Note A>
#     {368.0} <music21.stream.Measure 93 offset=368.0>
#         {0.0} <music21.note.Note E>
#     {372.0} <music21.stream.Measure 94 offset=372.0>
#         {0.0} <music21.note.Note F>
#         {1.5} <music21.note.Note C>
#         {3.0} <music21.note.Note F>
#     {376.0} <music21.stream.Measure 95 offset=376.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note B>
#         {3.0} <music21.note.Note D>
#     {380.0} <music21.stream.Measure 96 offset=380.0>
#         {0.0} <music21.note.Note E>
#         {1.0} <music21.note.Note E>
#         {1.5} <music21.note.Note B>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Rest eighth>
#         {3.5} <music21.note.Note G>
#     {384.0} <music21.stream.Measure 97 offset=384.0>
#         {0.0} <music21.note.Note E>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Note E>
#         {1.5} <music21.note.Note B>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note B>
#         {3.5} <music21.note.Note A>
#     {388.0} <music21.stream.Measure 98 offset=388.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note E>
#         {3.5} <music21.note.Note A>
#     {392.0} <music21.stream.Measure 99 offset=392.0>
#         {0.0} <music21.note.Note A>
#         {0.5} <music21.note.Note E>
#         {1.0} <music21.note.Note C>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C>
#     {396.0} <music21.stream.Measure 100 offset=396.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note E>
#         {3.5} <music21.note.Note A>
#     {400.0} <music21.stream.Measure 101 offset=400.0>
#         {0.0} <music21.note.Note A>
#         {0.5} <music21.note.Note E>
#         {1.0} <music21.note.Note C>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C>
#     {404.0} <music21.stream.Measure 102 offset=404.0>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note E>
#         {3.5} <music21.note.Note A>
#     {408.0} <music21.stream.Measure 103 offset=408.0>
#         {0.0} <music21.note.Note A>
#         {0.5} <music21.note.Note E>
#         {1.0} <music21.note.Note C>
#         {1.5} <music21.note.Note C>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note C>
#         {3.5} <music21.note.Note C>
#         {4.0} <music21.bar.Barline type=final>
# {0.0} <music21.stream.Part 0x23b6a6187f0>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.instrument.Bass 'Bass: Bass'>
#         {0.0} <music21.clef.Bass8vbClef>
#         {0.0} <music21.tempo.MetronomeMark Quarter=190.0>
#         {0.0} <music21.key.Key of C major>
#         {0.0} <music21.meter.TimeSignature 4/4>
#         {0.0} <music21.note.Rest 1.25ql>
#         {1.25} <music21.instrument.ElectricBass 'Electric Bass'>
#         {1.25} <music21.note.Rest 2.75ql>
#     {4.0} <music21.stream.Measure 2 offset=4.0>
#         {0.0} <music21.note.Rest whole>
#     {8.0} <music21.stream.Measure 3 offset=8.0>
#         {0.0} <music21.note.Rest whole>
#     {12.0} <music21.stream.Measure 4 offset=12.0>
#         {0.0} <music21.note.Rest whole>
#     {16.0} <music21.stream.Measure 5 offset=16.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note F>
#         {3.5} <music21.note.Note F#>
#     {20.0} <music21.stream.Measure 6 offset=20.0>
#         {0.0} <music21.note.Note F#>
#         {1.5} <music21.note.Note F>
#     {24.0} <music21.stream.Measure 7 offset=24.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note F>
#         {3.5} <music21.note.Note F#>
#     {28.0} <music21.stream.Measure 8 offset=28.0>
#         {0.0} <music21.note.Note F#>
#         {1.5} <music21.note.Note F>
#     {32.0} <music21.stream.Measure 9 offset=32.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {36.0} <music21.stream.Measure 10 offset=36.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {40.0} <music21.stream.Measure 11 offset=40.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {44.0} <music21.stream.Measure 12 offset=44.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {48.0} <music21.stream.Measure 13 offset=48.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {52.0} <music21.stream.Measure 14 offset=52.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {56.0} <music21.stream.Measure 15 offset=56.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {60.0} <music21.stream.Measure 16 offset=60.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {64.0} <music21.stream.Measure 17 offset=64.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {2.5} <music21.note.Note A>
#     {68.0} <music21.stream.Measure 18 offset=68.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {2.5} <music21.note.Note A>
#     {72.0} <music21.stream.Measure 19 offset=72.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {2.5} <music21.note.Note A>
#     {76.0} <music21.stream.Measure 20 offset=76.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {2.5} <music21.note.Note A>
#     {80.0} <music21.stream.Measure 21 offset=80.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {84.0} <music21.stream.Measure 22 offset=84.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {88.0} <music21.stream.Measure 23 offset=88.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {92.0} <music21.stream.Measure 24 offset=92.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {96.0} <music21.stream.Measure 25 offset=96.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {3.5} <music21.note.Note E>
#     {100.0} <music21.stream.Measure 26 offset=100.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {3.5} <music21.note.Note E>
#     {104.0} <music21.stream.Measure 27 offset=104.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {3.5} <music21.note.Note A>
#     {108.0} <music21.stream.Measure 28 offset=108.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {3.5} <music21.note.Note A>
#     {112.0} <music21.stream.Measure 29 offset=112.0>
#         {0.0} <music21.note.Note F>
#         {2.0} <music21.note.Note C>
#     {116.0} <music21.stream.Measure 30 offset=116.0>
#         {0.0} <music21.note.Note G>
#         {2.0} <music21.note.Note D>
#     {120.0} <music21.stream.Measure 31 offset=120.0>
#         {0.0} <music21.note.Note E>
#         {2.0} <music21.note.Note B>
#     {124.0} <music21.stream.Measure 32 offset=124.0>
#         {0.0} <music21.note.Note E>
#         {2.0} <music21.note.Note B>
#     {128.0} <music21.stream.Measure 33 offset=128.0>
#         {0.0} <music21.note.Rest whole>
#     {132.0} <music21.stream.Measure 34 offset=132.0>
#         {0.0} <music21.note.Rest whole>
#     {136.0} <music21.stream.Measure 35 offset=136.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note F>
#         {3.5} <music21.note.Note F#>
#     {140.0} <music21.stream.Measure 36 offset=140.0>
#         {0.0} <music21.note.Note F#>
#         {1.5} <music21.note.Note F>
#     {144.0} <music21.stream.Measure 37 offset=144.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note F>
#         {3.5} <music21.note.Note F#>
#     {148.0} <music21.stream.Measure 38 offset=148.0>
#         {0.0} <music21.note.Note F#>
#         {1.5} <music21.note.Note F>
#     {152.0} <music21.stream.Measure 39 offset=152.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {156.0} <music21.stream.Measure 40 offset=156.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {160.0} <music21.stream.Measure 41 offset=160.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {164.0} <music21.stream.Measure 42 offset=164.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {168.0} <music21.stream.Measure 43 offset=168.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {172.0} <music21.stream.Measure 44 offset=172.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {176.0} <music21.stream.Measure 45 offset=176.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {180.0} <music21.stream.Measure 46 offset=180.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {184.0} <music21.stream.Measure 47 offset=184.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {2.5} <music21.note.Note A>
#     {188.0} <music21.stream.Measure 48 offset=188.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {2.5} <music21.note.Note A>
#     {192.0} <music21.stream.Measure 49 offset=192.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {2.5} <music21.note.Note A>
#     {196.0} <music21.stream.Measure 50 offset=196.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {2.5} <music21.note.Note A>
#     {200.0} <music21.stream.Measure 51 offset=200.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {204.0} <music21.stream.Measure 52 offset=204.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {208.0} <music21.stream.Measure 53 offset=208.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {212.0} <music21.stream.Measure 54 offset=212.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {216.0} <music21.stream.Measure 55 offset=216.0>
#         {0.0} <music21.note.Note E>
#         {2.0} <music21.note.Note F>
#         {3.0} <music21.note.Note E>
#     {220.0} <music21.stream.Measure 56 offset=220.0>
#         {0.0} <music21.note.Note F>
#         {2.0} <music21.note.Note E>
#     {224.0} <music21.stream.Measure 57 offset=224.0>
#         {0.0} <music21.note.Note A>
#         {2.0} <music21.note.Note E>
#     {228.0} <music21.stream.Measure 58 offset=228.0>
#         {0.0} <music21.note.Note A>
#         {2.0} <music21.note.Note E>
#     {232.0} <music21.stream.Measure 59 offset=232.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note D>
#         {2.0} <music21.note.Note A>
#         {3.5} <music21.note.Note A>
#     {236.0} <music21.stream.Measure 60 offset=236.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note D>
#         {2.0} <music21.note.Note A>
#         {2.5} <music21.note.Note A>
#         {3.0} <music21.note.Note D>
#         {3.75} <music21.note.Rest 16th>
#     {240.0} <music21.stream.Measure 61 offset=240.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note E>
#         {3.5} <music21.note.Note E>
#     {244.0} <music21.stream.Measure 62 offset=244.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note A>
#         {3.5} <music21.note.Rest eighth>
#     {248.0} <music21.stream.Measure 63 offset=248.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note D>
#         {2.0} <music21.note.Note A>
#         {3.5} <music21.note.Note A>
#     {252.0} <music21.stream.Measure 64 offset=252.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note D>
#         {2.0} <music21.note.Note A>
#         {2.5} <music21.note.Note A>
#         {3.0} <music21.note.Note D>
#         {3.75} <music21.note.Rest 16th>
#     {256.0} <music21.stream.Measure 65 offset=256.0>
#         {0.0} <music21.note.Note A>
#         {2.0} <music21.note.Note G>
#     {260.0} <music21.stream.Measure 66 offset=260.0>
#         {0.0} <music21.note.Note F>
#         {2.0} <music21.note.Note E>
#         {3.0} <music21.note.Rest quarter>
#     {264.0} <music21.stream.Measure 67 offset=264.0>
#         {0.0} <music21.note.Rest whole>
#     {268.0} <music21.stream.Measure 68 offset=268.0>
#         {0.0} <music21.note.Rest whole>
#     {272.0} <music21.stream.Measure 69 offset=272.0>
#         {0.0} <music21.note.Rest whole>
#     {276.0} <music21.stream.Measure 70 offset=276.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note F>
#         {3.5} <music21.note.Note F#>
#     {280.0} <music21.stream.Measure 71 offset=280.0>
#         {0.0} <music21.note.Note F#>
#         {1.5} <music21.note.Note F>
#     {284.0} <music21.stream.Measure 72 offset=284.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note F>
#         {3.5} <music21.note.Note F#>
#     {288.0} <music21.stream.Measure 73 offset=288.0>
#         {0.0} <music21.note.Note F#>
#         {1.5} <music21.note.Note F>
#     {292.0} <music21.stream.Measure 74 offset=292.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {296.0} <music21.stream.Measure 75 offset=296.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {300.0} <music21.stream.Measure 76 offset=300.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {304.0} <music21.stream.Measure 77 offset=304.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {308.0} <music21.stream.Measure 78 offset=308.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {312.0} <music21.stream.Measure 79 offset=312.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {316.0} <music21.stream.Measure 80 offset=316.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {320.0} <music21.stream.Measure 81 offset=320.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {324.0} <music21.stream.Measure 82 offset=324.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {2.5} <music21.note.Note A>
#     {328.0} <music21.stream.Measure 83 offset=328.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {2.5} <music21.note.Note A>
#     {332.0} <music21.stream.Measure 84 offset=332.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {2.5} <music21.note.Note A>
#     {336.0} <music21.stream.Measure 85 offset=336.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {2.5} <music21.note.Note A>
#     {340.0} <music21.stream.Measure 86 offset=340.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {344.0} <music21.stream.Measure 87 offset=344.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {348.0} <music21.stream.Measure 88 offset=348.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {352.0} <music21.stream.Measure 89 offset=352.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {2.5} <music21.note.Note E>
#     {356.0} <music21.stream.Measure 90 offset=356.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {3.5} <music21.note.Note E>
#     {360.0} <music21.stream.Measure 91 offset=360.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {3.5} <music21.note.Note E>
#     {364.0} <music21.stream.Measure 92 offset=364.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {3.5} <music21.note.Note A>
#     {368.0} <music21.stream.Measure 93 offset=368.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note A>
#         {3.5} <music21.note.Note A>
#     {372.0} <music21.stream.Measure 94 offset=372.0>
#         {0.0} <music21.note.Note F>
#         {2.0} <music21.note.Note C>
#     {376.0} <music21.stream.Measure 95 offset=376.0>
#         {0.0} <music21.note.Note G>
#         {2.0} <music21.note.Note D>
#     {380.0} <music21.stream.Measure 96 offset=380.0>
#         {0.0} <music21.note.Note E>
#         {2.0} <music21.note.Note B>
#     {384.0} <music21.stream.Measure 97 offset=384.0>
#         {0.0} <music21.note.Note E>
#         {2.0} <music21.note.Note B>
#     {388.0} <music21.stream.Measure 98 offset=388.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note F>
#         {3.5} <music21.note.Note F#>
#     {392.0} <music21.stream.Measure 99 offset=392.0>
#         {0.0} <music21.note.Note F#>
#         {1.5} <music21.note.Note F>
#     {396.0} <music21.stream.Measure 100 offset=396.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note F>
#         {3.5} <music21.note.Note F#>
#     {400.0} <music21.stream.Measure 101 offset=400.0>
#         {0.0} <music21.note.Note F#>
#         {1.5} <music21.note.Note F>
#     {404.0} <music21.stream.Measure 102 offset=404.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note F>
#         {3.5} <music21.note.Note F#>
#     {408.0} <music21.stream.Measure 103 offset=408.0>
#         {0.0} <music21.note.Note F#>
#         {1.5} <music21.note.Note F>
#         {4.0} <music21.bar.Barline type=final>
# {0.0} <music21.stream.Part 0x23b6e326610>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.clef.BassClef>
#         {0.0} <music21.tempo.MetronomeMark Quarter=190.0>
#         {0.0} <music21.key.Key of C major>
#         {0.0} <music21.meter.TimeSignature 4/4>
#         {0.0} <music21.note.Rest 1.25ql>
#         {1.25} <music21.instrument.ElectricGuitar 'Rhythm single notes: Electric Guitar'>
#         {1.25} <music21.note.Rest 2.75ql>
#     {4.0} <music21.stream.Measure 2 offset=4.0>
#         {0.0} <music21.note.Rest whole>
#     {8.0} <music21.stream.Measure 3 offset=8.0>
#         {0.0} <music21.note.Rest whole>
#     {12.0} <music21.stream.Measure 4 offset=12.0>
#         {0.0} <music21.note.Rest whole>
#     {16.0} <music21.stream.Measure 5 offset=16.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note F>
#         {3.5} <music21.note.Note F#>
#     {20.0} <music21.stream.Measure 6 offset=20.0>
#         {0.0} <music21.note.Note F#>
#         {1.5} <music21.note.Note F>
#     {24.0} <music21.stream.Measure 7 offset=24.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note F>
#         {3.5} <music21.note.Note F#>
#     {28.0} <music21.stream.Measure 8 offset=28.0>
#         {0.0} <music21.note.Note F#>
#         {1.5} <music21.note.Note F>
#     {32.0} <music21.stream.Measure 9 offset=32.0>
#         {0.0} <music21.note.Rest whole>
#     {36.0} <music21.stream.Measure 10 offset=36.0>
#         {0.0} <music21.note.Rest whole>
#     {40.0} <music21.stream.Measure 11 offset=40.0>
#         {0.0} <music21.note.Rest whole>
#     {44.0} <music21.stream.Measure 12 offset=44.0>
#         {0.0} <music21.note.Rest whole>
#     {48.0} <music21.stream.Measure 13 offset=48.0>
#         {0.0} <music21.note.Rest whole>
#     {52.0} <music21.stream.Measure 14 offset=52.0>
#         {0.0} <music21.note.Rest whole>
#     {56.0} <music21.stream.Measure 15 offset=56.0>
#         {0.0} <music21.note.Rest whole>
#     {60.0} <music21.stream.Measure 16 offset=60.0>
#         {0.0} <music21.note.Rest whole>
#     {64.0} <music21.stream.Measure 17 offset=64.0>
#         {0.0} <music21.note.Rest whole>
#     {68.0} <music21.stream.Measure 18 offset=68.0>
#         {0.0} <music21.note.Rest whole>
#     {72.0} <music21.stream.Measure 19 offset=72.0>
#         {0.0} <music21.note.Rest whole>
#     {76.0} <music21.stream.Measure 20 offset=76.0>
#         {0.0} <music21.note.Rest whole>
#     {80.0} <music21.stream.Measure 21 offset=80.0>
#         {0.0} <music21.note.Rest whole>
#     {84.0} <music21.stream.Measure 22 offset=84.0>
#         {0.0} <music21.note.Rest whole>
#     {88.0} <music21.stream.Measure 23 offset=88.0>
#         {0.0} <music21.note.Rest whole>
#     {92.0} <music21.stream.Measure 24 offset=92.0>
#         {0.0} <music21.note.Rest whole>
#     {96.0} <music21.stream.Measure 25 offset=96.0>
#         {0.0} <music21.note.Rest whole>
#     {100.0} <music21.stream.Measure 26 offset=100.0>
#         {0.0} <music21.note.Rest whole>
#     {104.0} <music21.stream.Measure 27 offset=104.0>
#         {0.0} <music21.note.Rest whole>
#     {108.0} <music21.stream.Measure 28 offset=108.0>
#         {0.0} <music21.note.Rest whole>
#     {112.0} <music21.stream.Measure 29 offset=112.0>
#         {0.0} <music21.note.Rest whole>
#     {116.0} <music21.stream.Measure 30 offset=116.0>
#         {0.0} <music21.note.Rest whole>
#     {120.0} <music21.stream.Measure 31 offset=120.0>
#         {0.0} <music21.note.Rest whole>
#     {124.0} <music21.stream.Measure 32 offset=124.0>
#         {0.0} <music21.note.Rest whole>
#     {128.0} <music21.stream.Measure 33 offset=128.0>
#         {0.0} <music21.note.Rest whole>
#     {132.0} <music21.stream.Measure 34 offset=132.0>
#         {0.0} <music21.note.Rest whole>
#     {136.0} <music21.stream.Measure 35 offset=136.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note F>
#         {3.5} <music21.note.Note F#>
#     {140.0} <music21.stream.Measure 36 offset=140.0>
#         {0.0} <music21.note.Note F#>
#         {1.5} <music21.note.Note F>
#     {144.0} <music21.stream.Measure 37 offset=144.0>
#         {0.0} <music21.note.Note E>
#         {1.5} <music21.note.Note F>
#         {3.5} <music21.note.Note F#>
#     {148.0} <music21.stream.Measure 38 offset=148.0>
#         {0.0} <music21.note.Note F#>
#         {1.5} <music21.note.Note F>
#     {152.0} <music21.stream.Measure 39 offset=152.0>
#         {0.0} <music21.note.Rest whole>
#     {156.0} <music21.stream.Measure 40 offset=156.0>
#         {0.0} <music21.note.Rest whole>
#     {160.0} <music21.stream.Measure 41 offset=160.0>
#         {0.0} <music21.note.Rest whole>
#     {164.0} <music21.stream.Measure 42 offset=164.0>
#         {0.0} <music21.note.Rest whole>
#     {168.0} <music21.stream.Measure 43 offset=168.0>
#         {0.0} <music21.note.Rest whole>
#     {172.0} <music21.stream.Measure 44 offset=172.0>
#         {0.0} <music21.note.Rest whole>
#     {176.0} <music21.stream.Measure 45 offset=176.0>
#         {0.0} <music21.note.Rest whole>
#     {180.0} <music21.stream.Measure 46 offset=180.0>
#         {0.0} <music21.note.Rest whole>
#     {184.0} <music21.stream.Measure 47 offset=184.0>
#         {0.0} <music21.note.Rest whole>
#     {188.0} <music21.stream.Measure 48 offset=188.0>
#         {0.0} <music21.note.Rest whole>
#     {192.0} <music21.stream.Measure 49 offset=192.0>
#         {0.0} <music21.note.Rest whole>
#     {196.0} <music21.stream.Measure 50 offset=196.0>
#         {0.0} <music21.note.Rest whole>
#     {200.0} <music21.stream.Measure 51 offset=200.0>
#         {0.0} <music21.note.Rest whole>
#     {204.0} <music21.stream.Measure 52 offset=204.0>
#         {0.0} <music21.note.Rest whole>
#     {208.0} <music21.stream.Measure 53 offset=208.0>
#         {0.0} <music21.note.Rest whole>
#     {212.0} <music21.stream.Measure 54 offset=212.0>
# ...
#     {308.0} <music21.stream.Measure 78 offset=308.0>
#         {0.0} <music21.note.Unpitched object at 0x23b69df5a60>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b69df5b20>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b69df5c40>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b69df5d00>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b69df5dc0>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b69df5eb0>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b69df5f70>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b6a3c6070>
#         {3.75} <music21.note.Rest 16th>
#     {312.0} <music21.stream.Measure 79 offset=312.0>
#         {0.0} <music21.note.Unpitched object at 0x23b6a3c6190>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b6a3c6250>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b6a3c6310>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b6a3c6400>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b6a3c64c0>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b6a3c6580>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b6a3c6670>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b6a3c6730>
#         {3.75} <music21.note.Rest 16th>
#     {316.0} <music21.stream.Measure 80 offset=316.0>
#         {0.0} <music21.note.Unpitched object at 0x23b6a3c6850>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b6a3c6910>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b6a3c69d0>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b6a3c6ac0>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b6a3c6b80>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b6a3c6c40>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b6a3c6d60>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b6a3c6e20>
#         {3.75} <music21.note.Rest 16th>
#     {320.0} <music21.stream.Measure 81 offset=320.0>
#         {0.0} <music21.note.Unpitched object at 0x23b6a3c6f10>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b6a3de040>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b6a3de100>
#         {1.25} <music21.note.Rest 2.75ql>
#     {324.0} <music21.stream.Measure 82 offset=324.0>
#         {0.0} <music21.note.Rest eighth>
#         {0.5} <music21.note.Unpitched object at 0x23b6a3de280>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b6a3de340>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b6a3de400>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b6a3de4f0>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b6a3de5b0>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b6a3de670>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b6a3de760>
#         {3.75} <music21.note.Rest 16th>
#     {328.0} <music21.stream.Measure 83 offset=328.0>
#         {0.0} <music21.note.Unpitched object at 0x23b6a3de850>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b6a3de910>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b6a3dea00>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b6a3deac0>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b6a3deb80>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b6a3deca0>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b6a3ded60>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b6a3dee20>
#         {3.75} <music21.note.Rest 16th>
#     {332.0} <music21.stream.Measure 84 offset=332.0>
#         {0.0} <music21.note.Unpitched object at 0x23b6a3def40>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b69cf3040>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b69cf3100>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b69cf31f0>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b69cf32b0>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b69cf3370>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b69cf3460>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b69cf3520>
#         {3.75} <music21.note.Rest 16th>
#     {336.0} <music21.stream.Measure 85 offset=336.0>
#         {0.0} <music21.note.Unpitched object at 0x23b69cf3610>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b69cf3700>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b69cf37c0>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b69cf3880>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b69cf3970>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b69cf3a30>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b69cf3af0>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b69cf3c10>
#         {3.75} <music21.note.Rest 16th>
#     {340.0} <music21.stream.Measure 86 offset=340.0>
#         {0.0} <music21.note.Unpitched object at 0x23b69cf3d00>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b69cf3df0>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b69cf3eb0>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b69cf3f70>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b69cdd0a0>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b69cdd160>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b69cdd220>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b69cdd310>
#         {3.75} <music21.note.Rest 16th>
#     {344.0} <music21.stream.Measure 87 offset=344.0>
#         {0.0} <music21.note.Unpitched object at 0x23b69cdd400>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b69cdd4c0>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b69cdd5b0>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b69cdd670>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b69cdd730>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b69cdd820>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b69cdd8e0>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b69cdd9a0>
#         {3.75} <music21.note.Rest 16th>
#     {348.0} <music21.stream.Measure 88 offset=348.0>
#         {0.0} <music21.note.Unpitched object at 0x23b69cddaf0>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b69cddbb0>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b69cddc70>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b69cddd60>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b69cdde20>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b69cddee0>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b69cddfd0>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b69d830d0>
#         {3.75} <music21.note.Rest 16th>
#     {352.0} <music21.stream.Measure 89 offset=352.0>
#         {0.0} <music21.note.Unpitched object at 0x23b69d831c0>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b69d832b0>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b69d83370>
#         {1.25} <music21.note.Rest 2.75ql>
#     {356.0} <music21.stream.Measure 90 offset=356.0>
#         {0.0} <music21.note.Unpitched object at 0x23b69d83490>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b69d83550>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b69d83610>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b69d83700>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b69d837c0>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b69d83880>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b69d83970>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b69d83a30>
#         {3.75} <music21.note.Rest 16th>
#     {360.0} <music21.stream.Measure 91 offset=360.0>
#         {0.0} <music21.note.Unpitched object at 0x23b69d83b20>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b69d83c40>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b69d83d00>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b69d83dc0>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b69d83eb0>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b69d83f70>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b69d77070>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b69d77130>
#         {3.75} <music21.note.Rest 16th>
#     {364.0} <music21.stream.Measure 92 offset=364.0>
#         {0.0} <music21.note.Unpitched object at 0x23b69d77280>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b69d77340>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b69d77400>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b69d774f0>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b69d775b0>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b69d77670>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b69d77be0>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b69d77ca0>
#         {3.75} <music21.note.Rest 16th>
#     {368.0} <music21.stream.Measure 93 offset=368.0>
#         {0.0} <music21.note.Unpitched object at 0x23b69d77dc0>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b69d77e80>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b69d77f70>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b6a197070>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b6a197160>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b6a197220>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b6a197310>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b6a1973d0>
#         {3.75} <music21.note.Rest 16th>
#     {372.0} <music21.stream.Measure 94 offset=372.0>
#         {0.0} <music21.note.Unpitched object at 0x23b6a1974f0>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b6a1975b0>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b6a197670>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b6a197760>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b6a197820>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b6a197940>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b6a197a00>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b6a197af0>
#         {3.75} <music21.note.Rest 16th>
#     {376.0} <music21.stream.Measure 95 offset=376.0>
#         {0.0} <music21.note.Unpitched object at 0x23b6a197be0>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b6a197cd0>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b6a197d90>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b6a197e80>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b6a197f40>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b6a15b040>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b6a15b130>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b6a15b1f0>
#         {3.75} <music21.note.Rest 16th>
#     {380.0} <music21.stream.Measure 96 offset=380.0>
#         {0.0} <music21.note.Unpitched object at 0x23b6a15b310>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b6a15b3d0>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b6a15b4c0>
#         {1.25} <music21.note.Rest 16th>
#         {1.5} <music21.note.Unpitched object at 0x23b6a15b580>
#         {1.75} <music21.note.Rest 16th>
#         {2.0} <music21.note.Unpitched object at 0x23b6a15b6a0>
#         {2.25} <music21.note.Rest 16th>
#         {2.5} <music21.note.Unpitched object at 0x23b6a15b760>
#         {2.75} <music21.note.Rest 16th>
#         {3.0} <music21.note.Unpitched object at 0x23b6a15b850>
#         {3.25} <music21.note.Rest 16th>
#         {3.5} <music21.note.Unpitched object at 0x23b6a15b910>
#         {3.75} <music21.note.Rest 16th>
#     {384.0} <music21.stream.Measure 97 offset=384.0>
#         {0.0} <music21.note.Unpitched object at 0x23b6a15ba30>
#         {0.25} <music21.note.Rest 16th>
#         {0.5} <music21.note.Unpitched object at 0x23b6a15baf0>
#         {0.75} <music21.note.Rest 16th>
#         {1.0} <music21.note.Unpitched object at 0x23b6a15bbb0>
#         {1.25} <music21.note.Rest 2.75ql>
#         {4.0} <music21.bar.Barline type=final>

# %%
len(music.parts)
# Out:
# 12

# %% [markdown]
# 'offsetSeconds': 音符的起始時間（單位：秒）。
#
# 'durationSeconds': 音符的時值（單位：秒）。
#
# 'endTimeSeconds': 音符的結束時間（單位：秒）。
#
# 'element': 音符對象本身，可以獲取該音符的其他信息，例如音高、音量等。
#
# 'voiceIndex': 音符所在的聲部索引。

# %%
# 將MIDI文件轉換為音符
notes = music.flat.notes.secondsMap
notes
# Out:
# [{'offsetSeconds': 0.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 0.5,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 0.5,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 1.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 1.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 1.5,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 1.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 1.75,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 1.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 2.0,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 2.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 2.25,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 2.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 2.5,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 2.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 2.75,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 2.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 3.0,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 3.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 3.25,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 3.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 3.5,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 3.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 3.75,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 3.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 4.0,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 4.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 4.5,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 4.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 4.75,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 4.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 4.75,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 4.5,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 5.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 4.75,
#   'durationSeconds': 1.0,
#   'endTimeSeconds': 5.75,
#   'element': <music21.note.Note F>,
#   'voiceIndex': None},
#  {'offsetSeconds': 4.75,
#   'durationSeconds': 1.0,
#   'endTimeSeconds': 5.75,
#   'element': <music21.note.Note F>,
#   'voiceIndex': None},
#  {'offsetSeconds': 5.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 5.5,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 5.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 5.75,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 5.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 6.0,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 5.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 6.0,
#   'element': <music21.note.Note F#>,
#   'voiceIndex': None},
#  {'offsetSeconds': 5.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 6.0,
#   'element': <music21.note.Note F#>,
#   'voiceIndex': None},
#  {'offsetSeconds': 6.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 6.25,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 6.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 6.75,
#   'element': <music21.note.Note F#>,
#   'voiceIndex': None},
#  {'offsetSeconds': 6.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 6.75,
#   'element': <music21.note.Note F#>,
#   'voiceIndex': None},
#  {'offsetSeconds': 6.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 6.5,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 6.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 6.75,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 6.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 7.0,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 6.75,
#   'durationSeconds': 1.25,
#   'endTimeSeconds': 8.0,
#   'element': <music21.note.Note F>,
#   'voiceIndex': None},
#  {'offsetSeconds': 6.75,
#   'durationSeconds': 1.25,
#   'endTimeSeconds': 8.0,
#   'element': <music21.note.Note F>,
#   'voiceIndex': None},
#  {'offsetSeconds': 7.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 7.25,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 7.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 7.5,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 7.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 7.75,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 7.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 8.0,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 8.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 8.5,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 8.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 8.75,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 8.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 8.75,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 8.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 8.125,
#   'element': <music21.note.Unpitched object at 0x23b6a69e610>,
#   'voiceIndex': None},
#  {'offsetSeconds': 8.5,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 9.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 8.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 8.625,
#   'element': <music21.note.Unpitched object at 0x23b7193f2b0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 8.75,
#   'durationSeconds': 1.0,
#   'endTimeSeconds': 9.75,
#   'element': <music21.note.Note F>,
#   'voiceIndex': None},
#  {'offsetSeconds': 8.75,
#   'durationSeconds': 1.0,
#   'endTimeSeconds': 9.75,
#   'element': <music21.note.Note F>,
#   'voiceIndex': None},
#  {'offsetSeconds': 8.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 8.875,
#   'element': <music21.note.Unpitched object at 0x23b6a69e6d0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 9.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 9.5,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 9.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 9.125,
#   'element': <music21.note.Unpitched object at 0x23b6a69e790>,
#   'voiceIndex': None},
#  {'offsetSeconds': 9.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 9.75,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 9.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 9.625,
#   'element': <music21.note.Unpitched object at 0x23b7193f370>,
#   'voiceIndex': None},
#  {'offsetSeconds': 9.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 10.0,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 9.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 10.0,
#   'element': <music21.note.Note F#>,
#   'voiceIndex': None},
#  {'offsetSeconds': 9.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 10.0,
#   'element': <music21.note.Note F#>,
#   'voiceIndex': None},
#  {'offsetSeconds': 9.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 9.875,
#   'element': <music21.note.Unpitched object at 0x23b6a69e850>,
#   'voiceIndex': None},
#  {'offsetSeconds': 10.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 10.25,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 10.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 10.75,
#   'element': <music21.note.Note F#>,
#   'voiceIndex': None},
#  {'offsetSeconds': 10.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 10.75,
#   'element': <music21.note.Note F#>,
#   'voiceIndex': None},
#  {'offsetSeconds': 10.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 10.125,
#   'element': <music21.note.Unpitched object at 0x23b6a69e940>,
#   'voiceIndex': None},
#  {'offsetSeconds': 10.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 10.5,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 10.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 10.75,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 10.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 10.625,
#   'element': <music21.note.Unpitched object at 0x23b7193f4c0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 10.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 11.0,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 10.75,
#   'durationSeconds': 1.25,
#   'endTimeSeconds': 12.0,
#   'element': <music21.note.Note F>,
#   'voiceIndex': None},
#  {'offsetSeconds': 10.75,
#   'durationSeconds': 1.25,
#   'endTimeSeconds': 12.0,
#   'element': <music21.note.Note F>,
#   'voiceIndex': None},
#  {'offsetSeconds': 10.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 10.875,
#   'element': <music21.note.Unpitched object at 0x23b6a69ea00>,
#   'voiceIndex': None},
#  {'offsetSeconds': 11.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 11.25,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 11.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 11.125,
#   'element': <music21.note.Unpitched object at 0x23b6a69eac0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 11.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 11.5,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 11.375,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 11.5,
#   'element': <music21.note.Unpitched object at 0x23b6a881d60>,
#   'voiceIndex': None},
#  {'offsetSeconds': 11.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 11.75,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 11.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 11.625,
#   'element': <music21.note.Unpitched object at 0x23b6a881dc0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 11.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 12.0,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 12.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 12.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 12.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 12.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 12.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 12.5,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 12.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 12.125,
#   'element': <music21.note.Unpitched object at 0x23b6a69ebb0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 12.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 12.125,
#   'element': <music21.note.Unpitched object at 0x23b69043fa0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 12.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 12.375,
#   'element': <music21.note.Unpitched object at 0x23b68359370>,
#   'voiceIndex': None},
#  {'offsetSeconds': 12.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 12.75,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 12.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 12.625,
#   'element': <music21.note.Unpitched object at 0x23b7193f610>,
#   'voiceIndex': None},
#  {'offsetSeconds': 12.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 12.625,
#   'element': <music21.note.Unpitched object at 0x23b683594c0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 12.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 13.0,
#   'element': <music21.note.Note B>,
#   'voiceIndex': None},
#  {'offsetSeconds': 12.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 13.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 12.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 13.0,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 12.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 12.875,
#   'element': <music21.note.Unpitched object at 0x23b6a69ec70>,
#   'voiceIndex': None},
#  {'offsetSeconds': 12.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 12.875,
#   'element': <music21.note.Unpitched object at 0x23b68359550>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 13.5,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 13.25,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 13.25,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 13.125,
#   'element': <music21.note.Unpitched object at 0x23b6a69ed30>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 13.125,
#   'element': <music21.note.Unpitched object at 0x23b6567fac0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.25,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 14.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 13.5,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 13.375,
#   'element': <music21.note.Unpitched object at 0x23b6a69edf0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 13.375,
#   'element': <music21.note.Unpitched object at 0x23b68295e50>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.5,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 14.0,
#   'element': <music21.note.Note B>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 13.75,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 13.625,
#   'element': <music21.note.Unpitched object at 0x23b6a69eeb0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 13.625,
#   'element': <music21.note.Unpitched object at 0x23b7193f6d0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 13.625,
#   'element': <music21.note.Unpitched object at 0x23b68295eb0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 14.0,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 13.875,
#   'element': <music21.note.Unpitched object at 0x23b6a69ef70>,
#   'voiceIndex': None},
#  {'offsetSeconds': 13.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 13.875,
#   'element': <music21.note.Unpitched object at 0x23b68295f70>,
#   'voiceIndex': None},
#  {'offsetSeconds': 14.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 14.5,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 14.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 14.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 14.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 14.5,
#   'element': <music21.chord.Chord E4 A3 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 14.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 14.125,
#   'element': <music21.note.Unpitched object at 0x23b6a6b90a0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 14.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 14.125,
#   'element': <music21.note.Unpitched object at 0x23b682b00d0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 14.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 14.375,
#   'element': <music21.note.Unpitched object at 0x23b682b0190>,
#   'voiceIndex': None},
#  {'offsetSeconds': 14.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 14.75,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 14.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 14.75,
#   'element': <music21.chord.Chord C4 A3 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 14.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 14.625,
#   'element': <music21.note.Unpitched object at 0x23b7193f820>,
#   'voiceIndex': None},
#  {'offsetSeconds': 14.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 14.625,
#   'element': <music21.note.Unpitched object at 0x23b682b0250>,
#   'voiceIndex': None},
#  {'offsetSeconds': 14.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 15.0,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 14.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 15.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 14.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 15.0,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 14.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 14.875,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9160>,
#   'voiceIndex': None},
#  {'offsetSeconds': 14.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 14.875,
#   'element': <music21.note.Unpitched object at 0x23b682b0340>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 15.25,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 15.25,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 15.25,
#   'element': <music21.chord.Chord C4 A3 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 15.125,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9220>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 15.125,
#   'element': <music21.note.Unpitched object at 0x23b682b0400>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 15.5,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.25,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 16.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 15.5,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 15.375,
#   'element': <music21.note.Unpitched object at 0x23b6a6b92e0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 15.375,
#   'element': <music21.note.Unpitched object at 0x23b682b04c0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 15.75,
#   'element': <music21.note.Note G>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 15.75,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 15.625,
#   'element': <music21.note.Unpitched object at 0x23b6a6b93a0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 15.625,
#   'element': <music21.note.Unpitched object at 0x23b7193f8e0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 15.625,
#   'element': <music21.note.Unpitched object at 0x23b682b05b0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 16.0,
#   'element': <music21.note.Note G#>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 16.0,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 15.875,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9460>,
#   'voiceIndex': None},
#  {'offsetSeconds': 15.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 15.875,
#   'element': <music21.note.Unpitched object at 0x23b682b0670>,
#   'voiceIndex': None},
#  {'offsetSeconds': 16.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 16.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 16.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 16.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 16.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 16.5,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 16.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 16.125,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9550>,
#   'voiceIndex': None},
#  {'offsetSeconds': 16.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 16.125,
#   'element': <music21.note.Unpitched object at 0x23b682b0760>,
#   'voiceIndex': None},
#  {'offsetSeconds': 16.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 16.375,
#   'element': <music21.note.Unpitched object at 0x23b682b0850>,
#   'voiceIndex': None},
#  {'offsetSeconds': 16.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 16.75,
#   'element': <music21.chord.Chord C4 A3 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 16.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 16.625,
#   'element': <music21.note.Unpitched object at 0x23b7193fa30>,
#   'voiceIndex': None},
#  {'offsetSeconds': 16.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 16.625,
#   'element': <music21.note.Unpitched object at 0x23b682b0910>,
#   'voiceIndex': None},
#  {'offsetSeconds': 16.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 17.0,
#   'element': <music21.note.Note B>,
#   'voiceIndex': None},
#  {'offsetSeconds': 16.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 17.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 16.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 17.0,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 16.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 16.875,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9610>,
#   'voiceIndex': None},
#  {'offsetSeconds': 16.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 16.875,
#   'element': <music21.note.Unpitched object at 0x23b682b09d0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 17.5,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 17.25,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 17.25,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 17.125,
#   'element': <music21.note.Unpitched object at 0x23b6a6b96d0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 17.125,
#   'element': <music21.note.Unpitched object at 0x23b682b0a90>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.25,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 18.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 17.5,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 17.375,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9790>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 17.375,
#   'element': <music21.note.Unpitched object at 0x23b682b0bb0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.5,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 18.0,
#   'element': <music21.note.Note B>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 17.75,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 17.625,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9850>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 17.625,
#   'element': <music21.note.Unpitched object at 0x23b7193faf0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 17.625,
#   'element': <music21.note.Unpitched object at 0x23b682b0c70>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 18.0,
#   'element': <music21.chord.Chord E4 A3 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 17.875,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9910>,
#   'voiceIndex': None},
#  {'offsetSeconds': 17.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 17.875,
#   'element': <music21.note.Unpitched object at 0x23b682b0d90>,
#   'voiceIndex': None},
#  {'offsetSeconds': 18.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 18.5,
#   'element': <music21.note.Note F>,
#   'voiceIndex': None},
#  {'offsetSeconds': 18.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 18.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 18.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 18.5,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 18.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 18.125,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9a00>,
#   'voiceIndex': None},
#  {'offsetSeconds': 18.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 18.125,
#   'element': <music21.note.Unpitched object at 0x23b682b0e80>,
#   'voiceIndex': None},
#  {'offsetSeconds': 18.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 18.375,
#   'element': <music21.note.Unpitched object at 0x23b682b0f40>,
#   'voiceIndex': None},
#  {'offsetSeconds': 18.5,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 19.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 18.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 18.75,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 18.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 18.625,
#   'element': <music21.note.Unpitched object at 0x23b7193fc40>,
#   'voiceIndex': None},
#  {'offsetSeconds': 18.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 18.625,
#   'element': <music21.note.Unpitched object at 0x23b682b40a0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 18.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 19.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 18.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 19.0,
#   'element': <music21.chord.Chord A3 E4 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 18.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 18.875,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9ac0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 18.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 18.875,
#   'element': <music21.note.Unpitched object at 0x23b682b4160>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 19.25,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 19.25,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 19.125,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9b80>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 19.125,
#   'element': <music21.note.Unpitched object at 0x23b682b4220>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 19.5,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.25,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 20.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 19.5,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 19.375,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9c40>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 19.375,
#   'element': <music21.note.Unpitched object at 0x23b682b4310>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 19.75,
#   'element': <music21.note.Note G>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 19.75,
#   'element': <music21.chord.Chord E4 A3 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 19.625,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9d00>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 19.625,
#   'element': <music21.note.Unpitched object at 0x23b7193fd00>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 19.625,
#   'element': <music21.note.Unpitched object at 0x23b682b43d0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 20.0,
#   'element': <music21.note.Note G#>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 20.0,
#   'element': <music21.chord.Chord E4 A3 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 19.875,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9dc0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 19.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 19.875,
#   'element': <music21.note.Unpitched object at 0x23b682b4490>,
#   'voiceIndex': None},
#  {'offsetSeconds': 20.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 20.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 20.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 20.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 20.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 20.5,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 20.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 20.125,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9eb0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 20.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 20.125,
#   'element': <music21.note.Unpitched object at 0x23b682b45b0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 20.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 20.375,
#   'element': <music21.note.Unpitched object at 0x23b682b4670>,
#   'voiceIndex': None},
#  {'offsetSeconds': 20.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 20.75,
#   'element': <music21.chord.Chord E4 A3 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 20.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 20.625,
#   'element': <music21.note.Unpitched object at 0x23b7193fe50>,
#   'voiceIndex': None},
#  {'offsetSeconds': 20.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 20.625,
#   'element': <music21.note.Unpitched object at 0x23b682b4760>,
#   'voiceIndex': None},
#  {'offsetSeconds': 20.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 21.0,
#   'element': <music21.note.Note B>,
#   'voiceIndex': None},
#  {'offsetSeconds': 20.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 21.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 20.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 21.0,
#   'element': <music21.chord.Chord C4 A3 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 20.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 20.875,
#   'element': <music21.note.Unpitched object at 0x23b6a6b9f70>,
#   'voiceIndex': None},
#  {'offsetSeconds': 20.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 20.875,
#   'element': <music21.note.Unpitched object at 0x23b682b4820>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 21.5,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 21.25,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 21.25,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 21.125,
#   'element': <music21.note.Unpitched object at 0x23b6a43c070>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 21.125,
#   'element': <music21.note.Unpitched object at 0x23b682b48e0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.25,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 22.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 21.5,
#   'element': <music21.chord.Chord C4 A3 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 21.375,
#   'element': <music21.note.Unpitched object at 0x23b6a43c130>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 21.375,
#   'element': <music21.note.Unpitched object at 0x23b682b49d0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.5,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 22.0,
#   'element': <music21.note.Note B>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 21.75,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 21.625,
#   'element': <music21.note.Unpitched object at 0x23b6a43c1f0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 21.625,
#   'element': <music21.note.Unpitched object at 0x23b7193ff10>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 21.625,
#   'element': <music21.note.Unpitched object at 0x23b682b4a90>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 22.0,
#   'element': <music21.chord.Chord E4 A3 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 21.875,
#   'element': <music21.note.Unpitched object at 0x23b6a43c2b0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 21.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 21.875,
#   'element': <music21.note.Unpitched object at 0x23b682b4b50>,
#   'voiceIndex': None},
#  {'offsetSeconds': 22.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 22.5,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 22.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 22.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 22.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 22.5,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 22.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 22.125,
#   'element': <music21.note.Unpitched object at 0x23b6a43c3a0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 22.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 22.125,
#   'element': <music21.note.Unpitched object at 0x23b682b4ca0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 22.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 22.375,
#   'element': <music21.note.Unpitched object at 0x23b682b4d60>,
#   'voiceIndex': None},
#  {'offsetSeconds': 22.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 22.75,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 22.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 22.75,
#   'element': <music21.chord.Chord E4 A3 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 22.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 22.625,
#   'element': <music21.note.Unpitched object at 0x23b719520a0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 22.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 22.625,
#   'element': <music21.note.Unpitched object at 0x23b682b4e20>,
#   'voiceIndex': None},
#  {'offsetSeconds': 22.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 23.0,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 22.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 23.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 22.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 23.0,
#   'element': <music21.chord.Chord E4 A3 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 22.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 22.875,
#   'element': <music21.note.Unpitched object at 0x23b6a43c460>,
#   'voiceIndex': None},
#  {'offsetSeconds': 22.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 22.875,
#   'element': <music21.note.Unpitched object at 0x23b682b4f10>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 23.25,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 23.25,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 23.25,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 23.125,
#   'element': <music21.note.Unpitched object at 0x23b6a43c520>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 23.125,
#   'element': <music21.note.Unpitched object at 0x23b682b4fd0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 23.5,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.25,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 24.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 23.5,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 23.375,
#   'element': <music21.note.Unpitched object at 0x23b6a43c5b0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 23.375,
#   'element': <music21.note.Unpitched object at 0x23b6831c100>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 23.75,
#   'element': <music21.note.Note G>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 23.75,
#   'element': <music21.chord.Chord C4 A3 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 23.625,
#   'element': <music21.note.Unpitched object at 0x23b6a43c6a0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 23.625,
#   'element': <music21.note.Unpitched object at 0x23b71952160>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 23.625,
#   'element': <music21.note.Unpitched object at 0x23b6831c1f0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 24.0,
#   'element': <music21.note.Note G#>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 24.0,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 23.875,
#   'element': <music21.note.Unpitched object at 0x23b6a43c760>,
#   'voiceIndex': None},
#  {'offsetSeconds': 23.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 23.875,
#   'element': <music21.note.Unpitched object at 0x23b6831c2e0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 24.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 24.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 24.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 24.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 24.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 24.5,
#   'element': <music21.chord.Chord E4 A3 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 24.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 24.125,
#   'element': <music21.note.Unpitched object at 0x23b6a43cfa0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 24.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 24.125,
#   'element': <music21.note.Unpitched object at 0x23b6831c3d0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 24.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 24.375,
#   'element': <music21.note.Unpitched object at 0x23b6831c4c0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 24.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 24.75,
#   'element': <music21.chord.Chord A3 E4 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 24.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 24.625,
#   'element': <music21.note.Unpitched object at 0x23b719522b0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 24.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 24.625,
#   'element': <music21.note.Unpitched object at 0x23b6831c5b0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 24.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 25.0,
#   'element': <music21.note.Note B>,
#   'voiceIndex': None},
#  {'offsetSeconds': 24.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 25.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 24.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 25.0,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 24.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 24.875,
#   'element': <music21.note.Unpitched object at 0x23b6a43cf40>,
#   'voiceIndex': None},
#  {'offsetSeconds': 24.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 24.875,
#   'element': <music21.note.Unpitched object at 0x23b6831c670>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 25.5,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 25.25,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 25.25,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 25.125,
#   'element': <music21.note.Unpitched object at 0x23b6a43ce50>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 25.125,
#   'element': <music21.note.Unpitched object at 0x23b6831c760>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.25,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 26.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 25.5,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 25.375,
#   'element': <music21.note.Unpitched object at 0x23b6a43cd60>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 25.375,
#   'element': <music21.note.Unpitched object at 0x23b6831c820>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.5,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 26.0,
#   'element': <music21.note.Note B>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 25.75,
#   'element': <music21.chord.Chord A3 E4 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 25.625,
#   'element': <music21.note.Unpitched object at 0x23b6a43cd00>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 25.625,
#   'element': <music21.note.Unpitched object at 0x23b71952370>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 25.625,
#   'element': <music21.note.Unpitched object at 0x23b6831c8e0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 26.0,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 25.875,
#   'element': <music21.note.Unpitched object at 0x23b6a43cc10>,
#   'voiceIndex': None},
#  {'offsetSeconds': 25.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 25.875,
#   'element': <music21.note.Unpitched object at 0x23b6831c9d0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 26.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 26.5,
#   'element': <music21.note.Note F>,
#   'voiceIndex': None},
#  {'offsetSeconds': 26.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 26.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 26.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 26.5,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 26.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 26.125,
#   'element': <music21.note.Unpitched object at 0x23b6a43ca60>,
#   'voiceIndex': None},
#  {'offsetSeconds': 26.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 26.125,
#   'element': <music21.note.Unpitched object at 0x23b6831cac0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 26.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 26.375,
#   'element': <music21.note.Unpitched object at 0x23b6831cb80>,
#   'voiceIndex': None},
#  {'offsetSeconds': 26.5,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 27.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 26.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 26.75,
#   'element': <music21.chord.Chord C4 A3 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 26.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 26.625,
#   'element': <music21.note.Unpitched object at 0x23b719524c0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 26.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 26.625,
#   'element': <music21.note.Unpitched object at 0x23b6831cc70>,
#   'voiceIndex': None},
#  {'offsetSeconds': 26.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 27.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 26.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 27.0,
#   'element': <music21.chord.Chord A3 E4 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 26.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 26.875,
#   'element': <music21.note.Unpitched object at 0x23b6a43c910>,
#   'voiceIndex': None},
#  {'offsetSeconds': 26.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 26.875,
#   'element': <music21.note.Unpitched object at 0x23b6e7dc730>,
#   'voiceIndex': None},
#  {'offsetSeconds': 27.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 27.25,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 27.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 27.25,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 27.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 27.125,
#   'element': <music21.note.Unpitched object at 0x23b6a43c970>,
#   'voiceIndex': None},
#  {'offsetSeconds': 27.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 27.125,
#   'element': <music21.note.Unpitched object at 0x23b6e7dc4c0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 27.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 27.5,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 27.25,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 28.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 27.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 27.5,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 27.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 27.375,
# ...
#   'voiceIndex': None},
#  {'offsetSeconds': 73.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 73.125,
#   'element': <music21.note.Unpitched object at 0x23b6a085fa0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 73.25,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 74.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 73.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 73.5,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 73.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 73.375,
#   'element': <music21.note.Unpitched object at 0x23b6a4e7790>,
#   'voiceIndex': None},
#  {'offsetSeconds': 73.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 73.375,
#   'element': <music21.note.Unpitched object at 0x23b6a36e0d0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 73.5,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 74.0,
#   'element': <music21.note.Note B>,
#   'voiceIndex': None},
#  {'offsetSeconds': 73.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 73.75,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 73.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 73.625,
#   'element': <music21.note.Unpitched object at 0x23b6a4e7850>,
#   'voiceIndex': None},
#  {'offsetSeconds': 73.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 73.625,
#   'element': <music21.note.Unpitched object at 0x23b71976c70>,
#   'voiceIndex': None},
#  {'offsetSeconds': 73.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 73.625,
#   'element': <music21.note.Unpitched object at 0x23b6a36e190>,
#   'voiceIndex': None},
#  {'offsetSeconds': 73.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 74.0,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 73.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 73.875,
#   'element': <music21.note.Unpitched object at 0x23b6a4e7910>,
#   'voiceIndex': None},
#  {'offsetSeconds': 73.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 73.875,
#   'element': <music21.note.Unpitched object at 0x23b6a36e280>,
#   'voiceIndex': None},
#  {'offsetSeconds': 74.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 74.5,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 74.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 74.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 74.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 74.5,
#   'element': <music21.chord.Chord E4 A3 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 74.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 74.125,
#   'element': <music21.note.Unpitched object at 0x23b6a4e7a00>,
#   'voiceIndex': None},
#  {'offsetSeconds': 74.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 74.125,
#   'element': <music21.note.Unpitched object at 0x23b6a36e370>,
#   'voiceIndex': None},
#  {'offsetSeconds': 74.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 74.375,
#   'element': <music21.note.Unpitched object at 0x23b6a36e460>,
#   'voiceIndex': None},
#  {'offsetSeconds': 74.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 74.75,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 74.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 74.75,
#   'element': <music21.chord.Chord C4 A3 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 74.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 74.625,
#   'element': <music21.note.Unpitched object at 0x23b71976dc0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 74.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 74.625,
#   'element': <music21.note.Unpitched object at 0x23b6a36e520>,
#   'voiceIndex': None},
#  {'offsetSeconds': 74.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 75.0,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 74.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 75.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 74.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 75.0,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 74.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 74.875,
#   'element': <music21.note.Unpitched object at 0x23b6a4e7ac0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 74.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 74.875,
#   'element': <music21.note.Unpitched object at 0x23b6a36e610>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 75.25,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 75.25,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 75.25,
#   'element': <music21.chord.Chord C4 A3 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 75.125,
#   'element': <music21.note.Unpitched object at 0x23b6a4e7b80>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 75.125,
#   'element': <music21.note.Unpitched object at 0x23b6a36e6d0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 75.5,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.25,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 76.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 75.5,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 75.375,
#   'element': <music21.note.Unpitched object at 0x23b6a4e7c40>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 75.375,
#   'element': <music21.note.Unpitched object at 0x23b6a36e790>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 75.75,
#   'element': <music21.note.Note G>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 75.75,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 75.625,
#   'element': <music21.note.Unpitched object at 0x23b6a4e7d00>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 75.625,
#   'element': <music21.note.Unpitched object at 0x23b71976e80>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 75.625,
#   'element': <music21.note.Unpitched object at 0x23b6a36e8b0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 76.0,
#   'element': <music21.note.Note G#>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 76.0,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 75.875,
#   'element': <music21.note.Unpitched object at 0x23b6a4e7dc0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 75.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 75.875,
#   'element': <music21.note.Unpitched object at 0x23b6a36e970>,
#   'voiceIndex': None},
#  {'offsetSeconds': 76.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 76.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 76.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 76.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 76.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 76.5,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 76.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 76.125,
#   'element': <music21.note.Unpitched object at 0x23b6a4e7eb0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 76.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 76.125,
#   'element': <music21.note.Unpitched object at 0x23b6a36ea90>,
#   'voiceIndex': None},
#  {'offsetSeconds': 76.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 76.375,
#   'element': <music21.note.Unpitched object at 0x23b6a36eb50>,
#   'voiceIndex': None},
#  {'offsetSeconds': 76.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 76.75,
#   'element': <music21.chord.Chord C4 A3 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 76.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 76.625,
#   'element': <music21.note.Unpitched object at 0x23b71976fd0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 76.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 76.625,
#   'element': <music21.note.Unpitched object at 0x23b6a36ec40>,
#   'voiceIndex': None},
#  {'offsetSeconds': 76.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 77.0,
#   'element': <music21.note.Note B>,
#   'voiceIndex': None},
#  {'offsetSeconds': 76.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 77.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 76.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 77.0,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 76.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 76.875,
#   'element': <music21.note.Unpitched object at 0x23b6a4e7f70>,
#   'voiceIndex': None},
#  {'offsetSeconds': 76.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 76.875,
#   'element': <music21.note.Unpitched object at 0x23b6a36ed00>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 77.5,
#   'element': <music21.note.Note C>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 77.25,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 77.25,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 77.125,
#   'element': <music21.note.Unpitched object at 0x23b6bec7070>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 77.125,
#   'element': <music21.note.Unpitched object at 0x23b6a36edf0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.25,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 78.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 77.5,
#   'element': <music21.chord.Chord A3 C4 E4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 77.375,
#   'element': <music21.note.Unpitched object at 0x23b6bec7130>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 77.375,
#   'element': <music21.note.Unpitched object at 0x23b6a36eeb0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.5,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 78.0,
#   'element': <music21.note.Note B>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 77.75,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 77.625,
#   'element': <music21.note.Unpitched object at 0x23b6bec71f0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 77.625,
#   'element': <music21.note.Unpitched object at 0x23b719890d0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 77.625,
#   'element': <music21.note.Unpitched object at 0x23b6a36efa0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 78.0,
#   'element': <music21.chord.Chord E4 A3 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 77.875,
#   'element': <music21.note.Unpitched object at 0x23b6bec72b0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 77.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 77.875,
#   'element': <music21.note.Unpitched object at 0x23b6a36f0a0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 78.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 78.5,
#   'element': <music21.note.Note F>,
#   'voiceIndex': None},
#  {'offsetSeconds': 78.0,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 78.75,
#   'element': <music21.note.Note A>,
#   'voiceIndex': None},
#  {'offsetSeconds': 78.0,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 78.5,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 78.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 78.125,
#   'element': <music21.note.Unpitched object at 0x23b6bec73a0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 78.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 78.125,
#   'element': <music21.note.Unpitched object at 0x23b6a36f1c0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 78.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 78.375,
#   'element': <music21.note.Unpitched object at 0x23b6a36f280>,
#   'voiceIndex': None},
#  {'offsetSeconds': 78.5,
#   'durationSeconds': 0.5,
#   'endTimeSeconds': 79.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 78.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 78.75,
#   'element': <music21.chord.Chord C4 E4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 78.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 78.625,
#   'element': <music21.note.Unpitched object at 0x23b71989220>,
#   'voiceIndex': None},
#  {'offsetSeconds': 78.5,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 78.625,
#   'element': <music21.note.Unpitched object at 0x23b6a36f340>,
#   'voiceIndex': None},
#  {'offsetSeconds': 78.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 79.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 78.75,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 79.0,
#   'element': <music21.chord.Chord A3 E4 C4>,
#   'voiceIndex': None},
#  {'offsetSeconds': 78.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 78.875,
#   'element': <music21.note.Unpitched object at 0x23b6bec7460>,
#   'voiceIndex': None},
#  {'offsetSeconds': 78.75,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 78.875,
#   'element': <music21.note.Unpitched object at 0x23b6a36f430>,
#   'voiceIndex': None},
#  {'offsetSeconds': 79.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 79.25,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 79.0,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 79.25,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 79.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 79.125,
#   'element': <music21.note.Unpitched object at 0x23b6bec7520>,
#   'voiceIndex': None},
#  {'offsetSeconds': 79.0,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 79.125,
#   'element': <music21.note.Unpitched object at 0x23b6a36f4f0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 79.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 79.5,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 79.25,
#   'durationSeconds': 0.75,
#   'endTimeSeconds': 80.0,
#   'element': <music21.note.Note E>,
#   'voiceIndex': None},
#  {'offsetSeconds': 79.25,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 79.5,
#   'element': <music21.chord.Chord E4 C4 A3>,
#   'voiceIndex': None},
#  {'offsetSeconds': 79.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 79.375,
#   'element': <music21.note.Unpitched object at 0x23b6bec75e0>,
#   'voiceIndex': None},
#  {'offsetSeconds': 79.25,
#   'durationSeconds': 0.125,
#   'endTimeSeconds': 79.375,
#   'element': <music21.note.Unpitched object at 0x23b6a36f610>,
#   'voiceIndex': None},
#  {'offsetSeconds': 79.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 79.75,
#   'element': <music21.note.Note G>,
#   'voiceIndex': None},
#  {'offsetSeconds': 79.5,
#   'durationSeconds': 0.25,
#   'endTimeSeconds': 79.75,
#   'element': <music21.chord.Chord E4 A3 C4>,
#   'voiceIndex': None},
#  ...]

# %% [markdown]
# Lead: 主旋律樂器，通常是樂曲中最突出的旋律樂器，例如主唱或主奏樂器。
#
# Bass: 低音樂器，通常負責演奏樂曲中的低音部分，例如低音結他或低音提琴。
#
# Electric Bass: 電貝斯，是低音結他的電子版本，通常在搖滾、流行等音樂類型中使用。
#
# Rhythm chords: 和弦樂器，通常負責演奏和弦伴奏，例如節奏吉他或鋼琴。
#
# Kick: 重低音樂器，負責演奏樂曲中的節奏部分，例如貝斯鼓或大鼓。
#
# Low Tom 1: 低音筒鼓，通常用於演奏較低音域的鼓聲，例如低音打擊樂器。
#
# Mid Tom 2: 中音筒鼓，通常用於演奏中等音域的鼓聲，例如中音打擊樂器。
#
# Crash 1: 碰撞鈸，通常用於演奏高音域的鈸聲，例如演奏高音部分的鈸。
#
# Crash 2: 碰撞鈸，通常用於演奏高音域的鈸聲，例如演奏高音部分的鈸。

# %%
for part in instrument.partitionByInstrument(music).parts:
    print(part, part.partName)
# Out:
# <music21.stream.Part Electric Guitar> Lead
# <music21.stream.Part Bass> Bass
# <music21.stream.Part Electric Bass> Electric Bass
# <music21.stream.Part Acoustic Guitar> Rhythm chords
# <music21.stream.Part Percussion> Kick
# <music21.stream.Part Low Tom 1> Low Tom 1
# <music21.stream.Part Mid Tom 2> Mid Tom 2
# <music21.stream.Part Crash 1> Crash 1
# <music21.stream.Part Crash 2> Crash 2
